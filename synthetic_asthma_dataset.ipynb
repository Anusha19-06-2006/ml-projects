# %% [markdown]
# # **Asthma and its details**

# %% [markdown]
# Asthma is a chronic lung disease that inflames and narrows the airways, making it difficult to breathe. It's characterized by recurring symptoms such as wheezing, coughing, chest tightness, and shortness of breath. While there's no cure, asthma can be managed with proper treatment and by identifying and avoiding triggers.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Types of asthma**
# ### **Types of asthma include:**
#
# **Allergic asthma:** when allergies trigger asthma symptoms.
#
# **Cough-variant asthma:** when your only asthma symptom is a cough.
#
# **Exercise-induced asthma:** when exercise triggers asthma symptoms.
#
# **Occupational asthma:** when substances you breathe in at work cause you to develop asthma or trigger asthma attacks.
#
# **Asthma-COPD overlap syndrome (ACOS):** when you have both asthma and COPD (chronic obstructive pulmonary disease).
#
# ## **Symptoms of asthma**
# ### **Symptoms of asthma include:**
#
# 1.Shortness of breath
#
# 2.Wheezing
#
# 3.Chest tightness, pain or pressure
#
# 4.Cough
#
# You might have asthma most of the time (persistent asthma). Or you might feel fine in between asthma attacks (intermittent asthma).
#
#
# ### **Asthma causes**
# Experts aren’t sure what causes asthma. But you might be at a higher risk if you:
#
# - Live with allergies or eczema (atopy)
# - Were exposed to toxins, fumes or secondhand or thirdhand smoke (residue left behind after smoking), especially early in life
# - Have a biological parent with allergies or asthma
# - Experienced repeated respiratory infections (like RSV) as a child
#
#
# ### **Asthma triggers**
# Asthma triggers are anything that causes asthma symptoms or makes them worse. You might have one specific trigger or many. Common triggers include:
#
# - **Allergies:** pollen, dust mites, pet dander, other airborne allergens
# -**Cold air:** especially in winter
# - **Exercise:** especially intense physical activity and cold-weather sports
# - **Mold:** even if you’re not allergic
# - **Occupational exposures:** sawdust, flour, glues, latex, building materials
# - **Respiratory infections:** colds, flu and other respiratory illnesses
# - **Smoke:** smoking, secondhand smoke, thirdhand smoke
# - **Stress:** physical or emotional
# - **Strong chemicals or smells:** perfumes, nail polish, household cleaners, air fresheners
# - **Toxins in the air:** factory emissions, car exhaust, wildfire smoke
# Asthma triggers can bring on an attack right away. Or it might take hours or days for an attack to start after you’re exposure to a trigger.
#
# ###**Complications of asthma**
# Asthma can cause severe flare-ups that don’t get better with treatment (status asthmaticus). This can be fatal if you can’t get enough oxygen to your organs and tissues.
#
# ###**Diagnosis and Tests**
# How doctors diagnose asthma
# An allergist or pulmonologist diagnoses asthma by asking about your symptoms and performing lung function tests. They’ll ask about your personal and family medical history. It can be helpful to let them know what makes asthma symptoms worse and if anything helps you feel better.
#
# ###**Tests**
# Your provider might determine how well your lungs are working and rule out other conditions with:
#
# - **Allergy blood tests or skin tests:** These can determine if an allergy is triggering your asthma symptoms.
# - **Blood count:** Providers can look at eosinophil and immunoglobulin E (IgE) levels and target them for treatment if they’re elevated. Eosinophils and IgE can be elevated in certain types of asthma.
# - **Spirometry:** This is a common lung function test that measures how well air flows through your lungs.
# - **Chest X-rays or CT scans:** These can help your provider look for causes of your symptoms.
# - **A peak flow meter:** This can measure how much your airways are restricted during certain activities.

# %% [markdown]
# ## **Reading The Dataset**

# %%
import pandas as pd
data = pd.read_csv("/content/synthetic_asthma_dataset.csv")

# %% [markdown]
# **metadata**
#
# **Patient_ID**   - Unique identifier for each patient.
#
# **Age** - Age of the patient (1 to 89 years).
#
# **Gender**  - Gender of the patient (Male, Female, Other).
#
# **BMI** -  Body Mass Index (ranges from 15 to 45).
#
# **Smoking_Status** - Smoking history (Never, Former, Current).
#
# **Family_History** - Whether there's a family history of asthma (1 = Yes, 0 = No).
#
# **Allergies** - Allergens affecting the patient (None, Dust, Pollen, Pet Dander, Multiple).
#
# **Air_Pollution_Level**	- Pollution exposure level (Low, Moderate, High).
#
# **Physical_Activity_Level**	- Activity level (Sedentary, Moderate, Active).
#
# **Occupation_Type**	- Type of work environment (Indoor, Outdoor).
#
# **Comorbidities**	- Other health issues (None, Diabetes, Hypertension, Both).
#
# **Medication_Adherence**	-
# Float value (0 to 1) showing how well patients follow asthma medication schedules.
#
#
#
# **Number_of_ER_Visits**	- How often the patient visited ER for respiratory issues (0 to 6).
#
# **Peak_Expiratory_Flow**	- Lung function test result in L/min (150–600 L/min).
#
# **FeNO_Level**	- Fractional exhaled nitric oxide (FeNO), an inflammation biomarker in ppb.
#
# **Has_Asthma**	- Binary target: 1 = Has asthma, 0 = No asthma. Primary classification target.
#
# **Asthma_Control_Level**	- For those with asthma, indicates control level (Well Controlled, Not Controlled, Poorly Controlled). Only ~24% of entries have this value.

# %%
data
# Out:
#       Patient_ID  Age  Gender   BMI Smoking_Status  Family_History Allergies  \
# 0     ASTH100000   52  Female  27.6         Former               1       NaN
# 1     ASTH100001   15    Male  24.6         Former               0      Dust
# 2     ASTH100002   72  Female  17.6          Never               0       NaN
# 3     ASTH100003   61    Male  16.8          Never               0  Multiple
# 4     ASTH100004   21    Male  30.2          Never               0       NaN
# ...          ...  ...     ...   ...            ...             ...       ...
# 9995  ASTH109995   70    Male  25.0          Never               0       NaN
# 9996  ASTH109996   78  Female  24.8          Never               0    Pollen
# 9997  ASTH109997   58    Male  30.1         Former               1    Pollen
# 9998  ASTH109998   88  Female  31.2         Former               0    Pollen
# 9999  ASTH109999   13  Female  16.4         Former               1  Multiple
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               10000 non-null  object
#  1   Age                      10000 non-null  int64
#  2   Gender                   10000 non-null  object
#  3   BMI                      10000 non-null  float64
#  4   Smoking_Status           10000 non-null  object
#  5   Family_History           10000 non-null  int64
#  6   Allergies                7064 non-null   object
#  7   Air_Pollution_Level      10000 non-null  object
#  8   Physical_Activity_Level  10000 non-null  object
#  9   Occupation_Type          10000 non-null  object
#  10  Comorbidities            5033 non-null   object
#  11  Medication_Adherence     10000 non-null  float64
#  12  Number_of_ER_Visits      10000 non-null  int64
#  13  Peak_Expiratory_Flow     10000 non-null  float64
# ...

# %% [markdown]
# ### **Data Exploration**

# %%
data.isna().sum()
# Out:
# Patient_ID                    0
# Age                           0
# Gender                        0
# BMI                           0
# Smoking_Status                0
# Family_History                0
# Allergies                  2936
# Air_Pollution_Level           0
# Physical_Activity_Level       0
# Occupation_Type               0
# Comorbidities              4967
# Medication_Adherence          0
# Number_of_ER_Visits           0
# Peak_Expiratory_Flow          0
# FeNO_Level                    0
# Has_Asthma                    0
# Asthma_Control_Level       7567
# dtype: int64

# %%
data['Age'].unique()
# Out:
# array([52, 15, 72, 61, 21, 83, 87, 75, 88, 24,  3, 22, 53,  2, 30, 38, 64,
#        60, 33, 76, 58, 89, 49, 59, 42, 80, 62, 47, 51, 55,  7, 73, 39, 18,
#         4, 14,  9, 84, 71, 44,  8, 35, 78, 81, 36, 50,  6, 54, 63, 34, 74,
#        48, 40, 85, 82, 26, 41, 29, 45, 65,  1, 11,  5, 28, 12, 23, 37, 86,
#        27, 79, 77, 43, 13, 32, 66, 57, 70, 56, 19, 68, 17, 69, 16, 20, 67,
#        31, 25, 46, 10])

# %%
data['BMI'].unique()
# Out:
# array([27.6, 24.6, 17.6, 16.8, 30.2, 27.8, 32.3, 29.7, 23.1, 15. , 28. ,
#        19.9, 24.1, 27.1, 21.8, 20.9, 23.5, 19.8, 23.8, 20.3, 22.4, 22.8,
#        35.6, 28.8, 24.4, 27.2, 29.6, 26.4, 24.3, 20.1, 23.4, 24.2, 30.3,
#        21. , 20.6, 21.4, 22. , 26.6, 21.1, 25.6, 23.9, 29.2, 26.8, 22.2,
#        31. , 38.1, 21.7, 22.6, 18.5, 29.3, 34.6, 23.6, 20.5, 25.4, 28.2,
#        27.9, 18.8, 23.2, 25. , 31.3, 31.5, 30.8, 30.7, 16. , 31.1, 29.9,
#        20.2, 18.1, 17.9, 16.7, 27. , 20.4, 28.3, 32.8, 24.5, 21.6, 29.5,
#        26.2, 33.9, 36.4, 19.5, 26.3, 26.5, 22.9, 35.5, 22.3, 28.5, 20.8,
#        21.5, 32.6, 28.4, 16.5, 31.2, 16.2, 36.2, 25.8, 18.4, 16.1, 27.3,
#        33.4, 30.6, 22.7, 18. , 23. , 19.6, 21.2, 27.7, 22.5, 25.5, 19.1,
#        24.9, 19.2, 24.8, 21.3, 33.7, 18.3, 26.9, 28.1, 25.3, 16.3, 21.9,
#        34.4, 25.1, 31.7, 28.6, 29.8, 26.1, 30.1, 29. , 16.6, 30.9, 31.6,
#        34. , 27.4, 15.7, 38.5, 28.9, 17.8, 33.5, 24. , 19.7, 22.1, 25.2,
# ...

# %%
data['Allergies'].unique()
# Out:
# array([nan, 'Dust', 'Multiple', 'Pollen', 'Pets'], dtype=object)

# %%
data['Air_Pollution_Level'].unique()
# Out:
# array(['Moderate', 'Low', 'High'], dtype=object)

# %%
data['Asthma_Control_Level'].unique()
# Out:
# array([nan, 'Poorly Controlled', 'Not Controlled', 'Well Controlled'],
#       dtype=object)

# %%
data['Comorbidities'].unique()
# Out:
# array(['Diabetes', 'Both', nan, 'Hypertension'], dtype=object)

# %%
data['Family_History'].unique()
# Out:
# array([1, 0])

# %%
data['Has_Asthma'].unique()
# Out:
# array([0, 1])

# %%
data['Number_of_ER_Visits'].unique()
# Out:
# array([0, 2, 1, 3, 4, 5, 6])

# %%
data['Occupation_Type'].unique()
# Out:
# array(['Outdoor', 'Indoor'], dtype=object)

# %%
data['Physical_Activity_Level'].unique()
# Out:
# array(['Sedentary', 'Moderate', 'Active'], dtype=object)

# %%
data['Smoking_Status'].unique()
# Out:
# array(['Former', 'Never', 'Current'], dtype=object)

# %%
data.Gender.unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
data.replace({
    'Gender' : {'Female':0, 'Male':1, 'Other':2},
    'Smoking_Status': {'Former':0, 'Never':1, 'Current':2},
    'Allergies':{ 'Dust':1, 'Multiple':2, 'Pollen':3, 'Pets':4},
    'Air_Pollution_Level':{'Moderate':0, 'Low':1, 'High':2},
    'Physical_Activity_Level':{'Sedentary':0, 'Moderate':1, 'Active':2},
    'Occupation_Type':{'Outdoor':0, 'Indoor':1},
    'Comorbidities' : {'Diabetes':0, 'Both':0, 'Hypertension':4},
    'Asthma_Control_Level':{'Poorly Controlled':1, 'Not Controlled':2, 'Well Controlled':3}
},inplace = True)
# Out:
# /tmp/ipython-input-3181273625.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({

# %%
df = data.drop(labels=['Asthma_Control_Level','Comorbidities','Allergies'],axis = 1)

# %%
print(df.to_string())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X = df.drop(['Has_Asthma','Patient_ID'],axis =1)
y = df['Has_Asthma']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3 ,random_state =42)

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_train,y_train)
# Out:
# 0.8517142857142858

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix

a = accuracy_score(y_test,y_pred)
b = precision_score(y_test,y_pred)
c = recall_score(y_test,y_pred)
d = confusion_matrix(y_test,y_pred)

print("accuracy_score :", a)
print("precision_score : ",b)
print("recall_score : ",c)
print("confusion_matrix : ",d)
# Out:
# accuracy_score : 0.8683333333333333
# precision_score :  0.7602427921092565
# recall_score :  0.6788617886178862
# confusion_matrix :  [[2104  158]
#  [ 237  501]]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7000 entries, 9069 to 7270
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      7000 non-null   int64
#  1   Gender                   7000 non-null   int64
#  2   BMI                      7000 non-null   float64
#  3   Smoking_Status           7000 non-null   int64
#  4   Family_History           7000 non-null   int64
#  5   Air_Pollution_Level      7000 non-null   int64
#  6   Physical_Activity_Level  7000 non-null   int64
#  7   Occupation_Type          7000 non-null   int64
#  8   Medication_Adherence     7000 non-null   float64
#  9   Number_of_ER_Visits      7000 non-null   int64
#  10  Peak_Expiratory_Flow     7000 non-null   float64
#  11  FeNO_Level               7000 non-null   float64
# dtypes: float64(4), int64(8)
# memory usage: 710.9 KB

# %% [markdown]
# ### **User Input :Health Checkup**
# **Enter some details here**

# %%
'''
 'Gender' : {'Female':0, 'Male':1, 'Other':2},
    'Smoking_Status': {'Former':0, 'Never':1, 'Current':2},
    'Allergies':{ 'Dust':1, 'Multiple':2, 'Pollen':3, 'Pets':4},
    'Air_Pollution_Level':{'Moderate':0, 'Low':1, 'High':2},
    'Physical_Activity_Level':{'Sedentary':0, 'Moderate':1, 'Active':2},
    'Occupation_Type':{'Outdoor':0, 'Indoor':1},
    'Comorbidities' : {'Diabetes':0, 'Both':0, 'Hypertension':4},
    'Asthma_Control_Level':{'Poorly Controlled':1, 'Not Controlled':2, 'Well Controlled':3}
'''




Age = int(input("Enter your age : "))
Gender = int(input("Enter your gender- {'Female':0, 'Male':1, 'Other':2} : "))
BMI = float(input("Enter your Body mass index : "))
Smoking_Status = int(input("Enter  Smoking_Status {'Former':0, 'Never':1, 'Current':2} "))
Family_History = int(input("Enter Family_History of asthma  [1 - yes, 0 -no]"))
Air_Pollution_Level = int(input("'Air_Pollution_Level':{'Moderate':0, 'Low':1, 'High':2} : "))
Physical_Activity_Level = int(input("Physical_Activity_Level':{'Sedentary':0, 'Moderate':1, 'Active':2} : "))
Occupation_Type = int(input("'Occupation_Type':{'Outdoor':0, 'Indoor':1} : "))
Medication_Adherence = float(input("Enter Medication_Adherence  : "))
Number_of_ER_Visits  = int(input("Enter your Number_of_ER_Visits : "))
Peak_Expiratory_Flow = float(input("Enter your Peak_Expiratory_Flow : "))
FeNO_Level = float(input("Enter 'Fractional exhaled nitric oxide (FeNO)' :"))

user_input= [[Age,Gender,BMI,Smoking_Status,Family_History,Air_Pollution_Level,Physical_Activity_Level,Occupation_Type,Medication_Adherence,Number_of_ER_Visits,Peak_Expiratory_Flow,FeNO_Level]]

y_pred = model.predict(user_input)

if y_pred == 0:
  print(" Having No Asthma.")
else :
  print("Asthma Detected.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2063237736.py in <cell line: 0>()
#      16 Gender = int(input("Enter your gender- {'Female':0, 'Male':1, 'Other':2} : "))
#      17 BMI = float(input("Enter your Body mass index : "))
# ---> 18 Smoking_Status = int(input("Enter  Smoking_Status {'Former':0, 'Never':1, 'Current':2} "))
#      19 Family_History = int(input("Enter Family_History of asthma  [1 - yes, 0 -no]"))
#      20 Air_Pollution_Level = int(input("'Air_Pollution_Level':{'Moderate':0, 'Low':1, 'High':2} : "))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...
